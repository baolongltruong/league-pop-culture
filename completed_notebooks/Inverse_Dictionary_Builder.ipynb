# %%
champions_list = "Aatrox,Ahri,Akali,Alistar,Amumu,Anivia,Annie,Aphelios,Ashe,Aurelion Sol,Azir,Bard,Blitzcrank,Brand,Braum,Caitlyn,Camille,Cassiopeia,Cho'Gath,Corki,Darius,Diana,Dr. Mundo,Draven,Ekko,Elise,Evelynn,Ezreal,Fiddlesticks,Fiora,Fizz,Galio,Gangplank,Garen,Gnar,Gragas,Graves,Hecarim,Heimerdinger,Illaoi,Irelia,Ivern,Janna,Jarvan IV,Jax,Jayce,Jhin,Jinx,Kai'Sa,Kalista,Karma,Karthus,Kassadin,Katarina,Kayle,Kayn,Kennen,Kha'Zix,Kindred,Kled,Kog'Maw,LeBlanc,Lee Sin,Leona,Lillia,Lissandra,Lucian,Lulu,Lux,Malphite,Malzahar,Maokai,Master Yi,Miss Fortune,Mordekaiser,Morgana,Nami,Nasus,Nautilus,Neeko,Nidalee,Nocturne,Nunu and Willump,Olaf,Orianna,Ornn,Pantheon,Poppy,Pyke,Qiyana,Quinn,Rakan,Rammus,Rek'Sai,Rell,Renekton,Rengar,Riven,Rumble,Ryze,Samira,Sejuani,Senna,Seraphine,Sett,Shaco,Shen,Shyvana,Singed,Sion,Sivir,Skarner,Sona,Soraka,Swain,Sylas,Syndra,Tahm Kench,Taliyah,Talon,Taric,Teemo,Thresh,Tristana,Trundle,Tryndamere,Twisted Fate,Twitch,Udyr,Urgot,Varus,Vayne,Veigar,Vel'Koz,Vi,Viktor,Vladimir,Volibear,Warwick,Wukong,Xayah,Xerath,Xin Zhao,Yasuo,Yone,Yorick,Yuumi,Zac,Zed,Ziggs,Zilean,Zoe,Zyra"
champions_list = champions_list.split(",")
champions_list.append("Renata Glasc")
champions_list.append("Zeri")
champions_list.append("Vex")
champions_list.append("Akshan")
champions_list.append("Gwen")
champions_list.append("Viego")
champions_list = [x.lower() for x in champions_list]

# %%
champions_dict = {x: {x} for x in champions_list}

# %%
champions_dict
# Out:
# {'aatrox': {'aatrox'},
#  'ahri': {'ahri'},
#  'akali': {'akali'},
#  'alistar': {'alistar'},
#  'amumu': {'amumu'},
#  'anivia': {'anivia'},
#  'annie': {'annie'},
#  'aphelios': {'aphelios'},
#  'ashe': {'ashe'},
#  'aurelion sol': {'aurelion sol'},
#  'azir': {'azir'},
#  'bard': {'bard'},
#  'blitzcrank': {'blitzcrank'},
#  'brand': {'brand'},
#  'braum': {'braum'},
#  'caitlyn': {'caitlyn'},
#  'camille': {'camille'},
#  'cassiopeia': {'cassiopeia'},
#  "cho'gath": {"cho'gath"},
#  'corki': {'corki'},
#  'darius': {'darius'},
#  'diana': {'diana'},
#  'dr. mundo': {'dr. mundo'},
#  'draven': {'draven'},
#  'ekko': {'ekko'},
#  'elise': {'elise'},
#  'evelynn': {'evelynn'},
#  'ezreal': {'ezreal'},
#  'fiddlesticks': {'fiddlesticks'},
#  'fiora': {'fiora'},
#  'fizz': {'fizz'},
#  'galio': {'galio'},
#  'gangplank': {'gangplank'},
#  'garen': {'garen'},
#  'gnar': {'gnar'},
#  'gragas': {'gragas'},
#  'graves': {'graves'},
#  'hecarim': {'hecarim'},
# ...

# %% [markdown]
# # Baolong!

# %% [markdown]
# I know this is kind of tedious, but could you *please* try to add as many nicknames as well as common typos as you know for each champion. And then just run the rest of the functions and upload the files to drive.

# %%
champions_dict['aatrox'].add('atrox')

champions_dict['ahri'].add('ari')

champions_dict['alistar'].add('ali')

champions_dict['aphelios'].add('aphel')

champions_dict['aurelion sol'].add('aurelion')
champions_dict['aurelion sol'].add('sol')
champions_dict['aurelion sol'].add('asol')

champions_dict['blitzcrank'].add('blitz')

champions_dict['caitlyn'].add('cait')

champions_dict['cassiopeia'].add('cass')

champions_dict["cho'gath"].add('chogath')
champions_dict["cho'gath"].add('cho')
champions_dict["cho'gath"].add('gath')

champions_dict['dr. mundo'].add('dr mundo')
champions_dict['dr. mundo'].add('mundo')

champions_dict['evelynn'].add('eve')

champions_dict['ezreal'].add('ez')

champions_dict['fiddlesticks'].add('fiddle')
champions_dict['fiddlesticks'].add('fid')

champions_dict['gangplank'].add('gp')

champions_dict['gragas'].add('grag')

champions_dict['hecarim'].add('hec')

champions_dict['heimerdinger'].add('heim')


champions_dict['irelia'].add('irel')

champions_dict['jarvan iv'].add('jarvan')
champions_dict['jarvan iv'].add('j4')

champions_dict['jinx'].add('powder') #LOL

champions_dict["kai'sa"].add('kaisa')
champions_dict["kai'sa"].add('kai')
champions_dict["kai'sa"].add('sa')

champions_dict['kalista'].add('kali')

champions_dict['karthus'].add('karth')

champions_dict['kassadin'].add('kass')

champions_dict['katarina'].add('kat')

champions_dict["kha'zix"].add('khazix')
champions_dict["kha'zix"].add('kha')
champions_dict["kha'zix"].add('zix')
champions_dict["kha'zix"].add('k6')

champions_dict["kog'maw"].add('kog')
champions_dict["kog'maw"].add('maw')
champions_dict["kog'maw"].add('kogmaw')

champions_dict['leblanc'].add('lb')

champions_dict['lee sin'].add('lee')
champions_dict['lee sin'].add('sin')
champions_dict['lee sin'].add('leesin')

champions_dict['lissandra'].add('liss')

champions_dict['malphite'].add('malph')

champions_dict['malzahar'].add('malz')

champions_dict['maokai'].add('mao')

champions_dict['master yi'].add('master')
champions_dict['master yi'].add('yi')
champions_dict['master yi'].add('masteryi')

champions_dict['miss fortune'].add('mf')
champions_dict['miss fortune'].add('missfortune')
champions_dict['miss fortune'].add('miss')
champions_dict['miss fortune'].add('fortune')

champions_dict['mordekaiser'].add('morde')
champions_dict['mordekaiser'].add('mord')

champions_dict['morgana'].add('morg')

champions_dict['nautilus'].add('naut')

champions_dict['nidalee'].add('nid')

champions_dict['nocturne'].add('noc')

champions_dict['nunu and willump'].add('nunu')
champions_dict['nunu and willump'].add('willump')

champions_dict['orianna'].add('ori')

champions_dict['pantheon'].add('panth')

champions_dict["rek'sai"].add('rek')
champions_dict["rek'sai"].add('sai')
champions_dict["rek'sai"].add('reksai')

champions_dict['renekton'].add('renek')

champions_dict['riven'].add('riv')

champions_dict['samira'].add('sam')

champions_dict['sejuani'].add('sej')

champions_dict['seraphine'].add('sera')

champions_dict['shyvana'].add('shyv')

champions_dict['soraka'].add('raka')

champions_dict['tahm kench'].add('tahm')
champions_dict['tahm kench'].add('kench')
champions_dict['tahm kench'].add('tahmkench')

champions_dict['tristana'].add('trist')

champions_dict['trundle'].add('trund')

champions_dict['tryndamere'].add('trynd')

champions_dict['twisted fate'].add('twisted')
champions_dict['twisted fate'].add('fate')
champions_dict['twisted fate'].add('twistedfate')
champions_dict['twisted fate'].add('tf')

champions_dict['veigar'].add('veig')

champions_dict["vel'koz"].add('vel')
champions_dict["vel'koz"].add('koz')
champions_dict["vel'koz"].add('velkoz')

champions_dict['vi'].add('vy')

champions_dict['viktor'].add('vik')

champions_dict['vladimir'].add('vlad')

champions_dict['volibear'].add('voli')

champions_dict['warwick'].add('ww')

champions_dict['wukong'].add('wuk')

champions_dict['xerath'].add('xer')

champions_dict['xin zhao'].add('xin')
champions_dict['xin zhao'].add('zhao')
champions_dict['xin zhao'].add('xinzhao')

champions_dict['yasuo'].add('yas')

champions_dict['zilean'].add('zil')

champions_dict['renata glasc'].add('renata')
champions_dict['renata glasc'].add('glasc')
champions_dict['renata glasc'].add('renataglasc')

# %%
champions_dict
# Out:
# {'aatrox': {'aatrox', 'atrox'},
#  'ahri': {'ahri', 'ari'},
#  'akali': {'akali'},
#  'alistar': {'ali', 'alistar'},
#  'amumu': {'amumu'},
#  'anivia': {'anivia'},
#  'annie': {'annie'},
#  'aphelios': {'aphel', 'aphelios'},
#  'ashe': {'ashe'},
#  'aurelion sol': {'asol', 'aurelion', 'aurelion sol', 'sol'},
#  'azir': {'azir'},
#  'bard': {'bard'},
#  'blitzcrank': {'blitz', 'blitzcrank'},
#  'brand': {'brand'},
#  'braum': {'braum'},
#  'caitlyn': {'cait', 'caitlyn'},
#  'camille': {'camille'},
#  'cassiopeia': {'cass', 'cassiopeia'},
#  "cho'gath": {'cho', "cho'gath", 'chogath', 'gath'},
#  'corki': {'corki'},
#  'darius': {'darius'},
#  'diana': {'diana'},
#  'dr. mundo': {'dr mundo', 'dr. mundo', 'mundo'},
#  'draven': {'draven'},
#  'ekko': {'ekko'},
#  'elise': {'elise'},
#  'evelynn': {'eve', 'evelynn'},
#  'ezreal': {'ez', 'ezreal'},
#  'fiddlesticks': {'fid', 'fiddle', 'fiddlesticks'},
#  'fiora': {'fiora'},
#  'fizz': {'fizz'},
#  'galio': {'galio'},
# ...

# %%
inverted_dict = dict()

for k,v in champions_dict.items():
    for v_i in v:
        inverted_dict[v_i] = k

# %%
inverted_dict
# Out:
# {'aatrox': 'aatrox',
#  'atrox': 'aatrox',
#  'ari': 'ahri',
#  'ahri': 'ahri',
#  'akali': 'akali',
#  'ali': 'alistar',
#  'alistar': 'alistar',
#  'amumu': 'amumu',
#  'anivia': 'anivia',
#  'annie': 'annie',
#  'aphelios': 'aphelios',
#  'aphel': 'aphelios',
#  'ashe': 'ashe',
#  'asol': 'aurelion sol',
#  'aurelion sol': 'aurelion sol',
#  'sol': 'aurelion sol',
#  'aurelion': 'aurelion sol',
#  'azir': 'azir',
#  'bard': 'bard',
#  'blitz': 'blitzcrank',
#  'blitzcrank': 'blitzcrank',
#  'brand': 'brand',
#  'braum': 'braum',
#  'caitlyn': 'caitlyn',
#  'cait': 'caitlyn',
#  'camille': 'camille',
#  'cassiopeia': 'cassiopeia',
#  'cass': 'cassiopeia',
#  "cho'gath": "cho'gath",
#  'chogath': "cho'gath",
#  'cho': "cho'gath",
#  'gath': "cho'gath",
#  'corki': 'corki',
#  'darius': 'darius',
#  'diana': 'diana',
#  'mundo': 'dr. mundo',
#  'dr. mundo': 'dr. mundo',
#  'dr mundo': 'dr. mundo',
#  'draven': 'draven',
#  'ekko': 'ekko',
#  'elise': 'elise',
#  'eve': 'evelynn',
# ...

# %%
import pickle

pickle.dump(inverted_dict, open( "data/inverted_dict.pkl", "wb" ) )

# %% [markdown]
# $$
# \text{Thank you}
# $$
